# %%
import pandas as pd

df = pd.read_csv("train_subset.csv", encoding="UTF-16LE")
print("Data 10 rows", df[:10])
# Out:
# Data 10 rows                      id  click      hour    C1  banner_pos   site_id  \
# 0   1000009418151094273      0  14102100  1005           0  1fbe01fe
# 1  10000169349117863715      0  14102100  1005           0  1fbe01fe
# 2  10000371904215119486      0  14102100  1005           0  1fbe01fe
# 3  10000640724480838376      0  14102100  1005           0  1fbe01fe
# 4  10000679056417042096      0  14102100  1005           1  fe8cc448
# 5  10000720757801103869      0  14102100  1005           0  d6137915
# 6  10000724729988544911      0  14102100  1005           0  8fda644b
# 7  10000918755742328737      0  14102100  1005           1  e151e245
# 8  10000949271186029916      1  14102100  1005           0  1fbe01fe
# 9  10001264480619467364      0  14102100  1002           0  84c7ba46
#
#   site_domain site_category    app_id app_domain ...  device_type  \
# 0    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
# ...

# %%
index = df.index
columns = df.columns
values = df.values

print("Index \n", index, "\n Values \n", values, "\n Columns \n", columns)
# Out:
# Index
#  RangeIndex(start=0, stop=9999, step=1)
#  Values
#  [[1000009418151094273 0 14102100 ... 35 -1 79]
#  [10000169349117863715 0 14102100 ... 35 100084 79]
#  [10000371904215119486 0 14102100 ... 35 100084 79]
#  ...
#  [11384401992895341158 1 14102100 ... 35 -1 79]
#  [11384416194059429451 1 14102100 ... 431 -1 117]
#  [11384658010851781062 0 14102100 ... 297 100111 61]]
#  Columns
#  Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %%
#print(df['click']==1)

Y = df['click']
#X = df.loc[:, df.columns != 'click']

X = df.drop('click', axis=1)
clicks_one = df.loc[df['click'] == 1]
clicks_one
X
# Out:
#                         id      hour    C1  banner_pos   site_id site_domain  \
# 0      1000009418151094273  14102100  1005           0  1fbe01fe    f3845767
# 1     10000169349117863715  14102100  1005           0  1fbe01fe    f3845767
# 2     10000371904215119486  14102100  1005           0  1fbe01fe    f3845767
# 3     10000640724480838376  14102100  1005           0  1fbe01fe    f3845767
# 4     10000679056417042096  14102100  1005           1  fe8cc448    9166c161
# 5     10000720757801103869  14102100  1005           0  d6137915    bb1ef334
# 6     10000724729988544911  14102100  1005           0  8fda644b    25d4cfcd
# 7     10000918755742328737  14102100  1005           1  e151e245    7e091613
# 8     10000949271186029916  14102100  1005           0  1fbe01fe    f3845767
# 9     10001264480619467364  14102100  1002           0  84c7ba46    c4e18dd6
# 10    10001868339616595934  14102100  1005           1  e151e245    7e091613
# ...

# %%
import matplotlib.pyplot as plt

print(columns)
print(X.loc[:,['hour', 'banner_pos']])

plt.scatter(X.loc[:,'banner_pos'], Y)
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')
#           hour  banner_pos
# 0     14102100           0
# 1     14102100           0
# 2     14102100           0
# 3     14102100           0
# 4     14102100           1
# 5     14102100           0
# 6     14102100           0
# 7     14102100           1
# 8     14102100           0
# 9     14102100           0
# 10    14102100           1
# 11    14102100           0
# 12    14102100           0
# 13    14102100           0
# 14    14102100           0
# 15    14102100           0
# 16    14102100           0
# 17    14102100           0
# 18    14102100           1
# 19    14102100           0
# 20    14102100           0
# 21    14102100           0
# ...

# %%
df.corr()
# Out:
#                         id     click  hour        C1  banner_pos  device_type  \
# id                1.000000  0.005162   NaN -0.004288   -0.010429     0.000495
# click             0.005162  1.000000   NaN -0.051620    0.025452    -0.054040
# hour                   NaN       NaN   NaN       NaN         NaN          NaN
# C1               -0.004288 -0.051620   NaN  1.000000    0.367789     0.966383
# banner_pos       -0.010429  0.025452   NaN  0.367789    1.000000     0.381344
# device_type       0.000495 -0.054040   NaN  0.966383    0.381344     1.000000
# device_conn_type  0.000606 -0.030397   NaN  0.116742    0.050567     0.106012
# C14               0.011723 -0.087614   NaN  0.127263    0.139919     0.163293
# C15              -0.002444 -0.061517   NaN  0.052629   -0.058076     0.056524
# C16               0.004793  0.139546   NaN -0.009145   -0.095433    -0.020132
# C17               0.012254 -0.081130   NaN  0.134913    0.131191     0.175768
# ...

# %%
df.cov()
# Out:
#                             id         click  hour            C1  \
# id                8.140390e+36  5.540511e+15   0.0 -1.349619e+16
# click             5.540511e+15  1.415210e-01   0.0 -2.142425e-02
# hour              0.000000e+00  0.000000e+00   0.0  0.000000e+00
# C1               -1.349619e+16 -2.142425e-02   0.0  1.217155e+00
# banner_pos       -1.204857e+16  3.876893e-03   0.0  1.642973e-01
# device_type       8.499155e+14 -1.223853e-02   0.0  6.418428e-01
# device_conn_type  1.117554e+15 -7.392668e-03   0.0  8.326588e-02
# C14               1.050051e+20 -1.034749e+02   0.0  4.407849e+02
# C15              -8.013927e+16 -2.659740e-01   0.0  6.673104e-01
# C16               5.117839e+17  1.964794e+00   0.0 -3.776027e-01
# C17               1.346631e+19 -1.175575e+01   0.0  5.733028e+01
# C18              -5.754608e+15  1.655233e-02   0.0  1.301482e-01
# C19               2.500746e+18  5.798520e+00   0.0 -1.477203e+01
# ...

# %%
plt.matshow(df.corr())

# %%
import seaborn as sns
corr = df.corr()
click_corr = corr.loc['click', :]
click_corr

#High correlation
# device type  -  C1
# C14  -  C17

# sns.heatmap(corr, 
#             xticklabels=corr.columns.values,
#             yticklabels=corr.columns.values)
# Out:
# id                  0.005162
# click               1.000000
# hour                     NaN
# C1                 -0.051620
# banner_pos          0.025452
# device_type        -0.054040
# device_conn_type   -0.030397
# C14                -0.087614
# C15                -0.061517
# C16                 0.139546
# C17                -0.081130
# C18                 0.035809
# C19                 0.065862
# C20                -0.014943
# C21                -0.151886
# Name: click, dtype: float64
